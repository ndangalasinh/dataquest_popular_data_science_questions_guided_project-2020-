# %%
#import the libraries
import pandas as pd

# %%
data = pd.read_csv('Tower120buffer.csv')

# %%
data
# Out:
#       No         Site_Name        Lon       Lat        Village       Cell  \
# 0      1  S008_ISAR-Rubona  29.772220 -2.489660         Rubona   Kiruhura
# 1      2      S010_Gikonko  29.856610 -2.484250       Rugarama    Gikonko
# 2      3      S017_Kanyaru  29.676580 -2.786220          Nteko       Fugi
# 3      4    S019_Gasarenda  29.490730 -2.507140           Muse  Gasarenda
# 4      5      S021_Mushubi  29.421060 -2.419050      Nyamaberi    Gifurwe
# ..   ...               ...        ...       ...            ...        ...
# 631  667      2KAR_KARONGI  29.374830 -2.148270  Bucyurabuhoro     Rubazo
# 632  668       2NYZ_NYANZA  29.750025 -2.357893         Kivumu     Nyanza
# 633  669         2HUY_HUYE  29.684610 -2.564690        Karambi    Shyembe
# 634  670              Huye  29.684532 -2.564608      Ngobagoba       Sovu
# 635  671            MUGOGO  29.565720 -1.586366        Kankima    Rukondo
#
#          Sector   District Province  Tower_Heig  RASTERVALU  obst_hgt  \
# ...

# %%
#data[['Tower_Heig','RASTERVALU','obst_hgt']] = data[['Tower_Heig','RASTERVALU','obst_hgt']].apply(str)
data['Tower_Heig'] = data['Tower_Heig'].apply(str)
data['RASTERVALU'] = data['RASTERVALU'].apply(str)
data['obst_hgt'] = data['obst_hgt'].apply(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# No            636 non-null int64
# Site_Name     636 non-null object
# Lon           636 non-null float64
# Lat           636 non-null float64
# Village       636 non-null object
# Cell          636 non-null object
# Sector        636 non-null object
# District      636 non-null object
# Province      636 non-null object
# Tower_Heig    636 non-null object
# RASTERVALU    636 non-null object
# obst_hgt      636 non-null object
# BUFF_DIST     636 non-null float64
# ORIG_FID      636 non-null int64
# Name          636 non-null object
# descriptio    636 non-null object
# second        636 non-null int64
# third         636 non-null int64
# dtypes: float64(3), int64(4), object(11)
# memory usage: 89.6+ KB

# %%
data['Combined_info'] = 'Site_name:'+data['Site_Name']+' '+'Terrain Elevation:'+data['RASTERVALU']+' '+'Height AGL:'+data['Tower_Heig']+' '+'Obstacle Height:'+data['obst_hgt']

# %%
data
# Out:
#       No         Site_Name        Lon       Lat        Village       Cell  \
# 0      1  S008_ISAR-Rubona  29.772220 -2.489660         Rubona   Kiruhura
# 1      2      S010_Gikonko  29.856610 -2.484250       Rugarama    Gikonko
# 2      3      S017_Kanyaru  29.676580 -2.786220          Nteko       Fugi
# 3      4    S019_Gasarenda  29.490730 -2.507140           Muse  Gasarenda
# 4      5      S021_Mushubi  29.421060 -2.419050      Nyamaberi    Gifurwe
# ..   ...               ...        ...       ...            ...        ...
# 631  667      2KAR_KARONGI  29.374830 -2.148270  Bucyurabuhoro     Rubazo
# 632  668       2NYZ_NYANZA  29.750025 -2.357893         Kivumu     Nyanza
# 633  669         2HUY_HUYE  29.684610 -2.564690        Karambi    Shyembe
# 634  670              Huye  29.684532 -2.564608      Ngobagoba       Sovu
# 635  671            MUGOGO  29.565720 -1.586366        Kankima    Rukondo
#
#          Sector   District Province Tower_Heig RASTERVALU obst_hgt  BUFF_DIST  \
# ...

# %%
data.to_csv(r'C:\Users\fidele\Desktop\export_dataframe.csv')
